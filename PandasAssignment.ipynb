# %% [markdown]
# ## Ex 1 Getting and Knowing your Data

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
# Step 2. Import the dataset from this address.

chipo = pd.read_csv('chipotle.csv')

# %%
# Step 3. Assign it to a variable called chipo.

chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Step 4. See the first 10 entries

chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
# Step 5. What is the number of observations in the dataset?

row_count = chipo.shape[0]
print('Number of observations in dataset :',row_count)
# Out:
# Number of observations in dataset : 4622

# %%
# Step 6. What is the number of columns in the dataset?

col_count = len(chipo.columns)
print("Number of columns in dataset :",col_count)
# Out:
# Number of columns in dataset : 5

# %%
# Step 7. Print the name of all the columns.

chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# Step 8. How is the dataset indexed?

index_type = type(chipo.index)
print("Type of index:", index_type)
# Out:
# Type of index: <class 'pandas.core.indexes.range.RangeIndex'>

# %%
# Step 9. Which was the most-ordered item?

item_orders = chipo.groupby('item_name')['quantity'].sum()

most_ordered_itemname = item_orders.idxmax()
print("Most-ordered item name:", most_ordered_itemname)
# Out:
# Most-ordered item name: Chicken Bowl

# %%
# Step 10. For the most-ordered item, how many items were ordered?

item_orders = chipo.groupby('item_name')['quantity'].sum()

max_quantity_ordered = item_orders.max()
print("Quantity ordered for the most-ordered item:", max_quantity_ordered)
# Out:
# Quantity ordered for the most-ordered item: 761

# %%
# Step 11. What was the most ordered item in the choice_description column?

choice_orders = chipo.groupby('choice_description')['quantity'].sum()

most_ordered_choice = choice_orders.idxmax()
max_quantity_ordered_choice = choice_orders.max()

print("Most-ordered item in the choice_description column:", most_ordered_choice)
print("Total quantity ordered for the most-ordered choice:", max_quantity_ordered_choice)
# Out:
# Most-ordered item in the choice_description column: [Diet Coke]
# Total quantity ordered for the most-ordered choice: 159

# %%
# Step 12. How many items were orderd in total?

total_ordered = chipo['quantity'].sum()

print("Total number of items ordered:", total_ordered)
# Out:
# Total number of items ordered: 4972

# %%
# Step 13. Turn the item price into a float

chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype(float)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3044\2583011104.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   chipo['item_price'] = chipo['item_price'].str.replace('$', '').astype(float)

# %%
# Step 13.a. Check the item price type

print(chipo['item_price'].dtype)
# Out:
# float64

# %%
# Step 13.b. Create a lambda function and change the type of item price

# convert_to_float = lambda x: float(x.strip('$'))
# chipo['item_price'] = chipo['item_price'].apply(convert_to_float)

# %%
# Step 13.c. Check the item price type

# print(chipo['item_price'].dtype)

# %%
# Step 14. How much was the revenue for the period in the dataset

chipo['Revenue'] = chipo['quantity'] * chipo['item_price']
total_revenue = chipo['Revenue'].sum()

print("Total revenue for the period:", total_revenue)
# Out:
# Total revenue for the period: 39237.02

# %%
# Step 15. How many orders were made in the period?

num_orders = chipo['order_id'].nunique()

print("Total number of orders made in the period:", num_orders)
# Out:
# Total number of orders made in the period: 1834

# %%
# Step 16. What is the average revenue amount per order?

average_revenue_per_order = total_revenue / num_orders

print("Average revenue amount per order:", average_revenue_per_order)
# Out:
# Average revenue amount per order: 21.39423118865867

# %%
# Step 17. How many different items are sold?

num_unique_items = chipo['item_name'].nunique()

print("Number of different items sold:", num_unique_items)
# Out:
# Number of different items sold: 50

# %% [markdown]
# #

# %% [markdown]
# ## Ex 2 Getting and Knowing your Data

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
# Step 2. Import the dataset from this address

users = pd.read_csv('user.csv')

# %%
# Step 3. Assign it to a variable called users and use the 'user_id' as index

users.set_index('user_id')
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %%
# Step 4. See the first 25 entries

users.head(25)
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# ...

# %%
# Step 5. See the last 10 entries

users.tail(10)
# Out:
#      user_id  age gender     occupation zip_code
# 933      934   61      M       engineer    22902
# 934      935   42      M         doctor    66221
# 935      936   24      M          other    32789
# 936      937   48      M       educator    98072
# 937      938   38      F     technician    55038
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
# Step 6. What is the number of observations in the dataset?

row_count = users.shape[0]
print('Number of observations in dataset :',row_count)
# Out:
# Number of observations in dataset : 943

# %%
# Step 7. What is the number of columns in the dataset?

col_count = len(users.columns)
print("Number of columns in dataset :",col_count)
# Out:
# Number of columns in dataset : 5

# %%
# Step 8. Print the name of all the columns.

users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
# Step 9. How is the dataset indexed?

index_type = type(users.index)
print("Type of index:", index_type)
# Out:
# Type of index: <class 'pandas.core.indexes.range.RangeIndex'>

# %%
# Step 10. What is the data type of each column?

users.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
# Step 11. Print only the occupation column

users[['occupation']]
# Out:
#         occupation
# 0       technician
# 1            other
# 2           writer
# 3       technician
# 4            other
# ..             ...
# 938        student
# 939  administrator
# 940        student
# 941      librarian
# 942        student
#
# [943 rows x 1 columns]

# %%
# Step 12. How many different occupations are in this dataset?

users.occupation

occupation = users['occupation'].nunique()

print("Number of different occupations:", occupation)
# Out:
# Number of different occupations: 21

# %%
# Step 13. What is the most frequent occupation?

occupation = users['occupation']

most_frequent_occupation = occupation.value_counts().idxmax()

print("Most frequent Occupation:", most_frequent_occupation)
# Out:
# Most frequent Occupation: student

# %%
# Step 14. Summarize the DataFrame.

users.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
# Step 15. Summarize all the columns

users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     943 non-null    int64
#  1   age         943 non-null    int64
#  2   gender      943 non-null    object
#  3   occupation  943 non-null    object
#  4   zip_code    943 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 37.0+ KB

# %%
# Step 16. Summarize only the occupation column

users['occupation'].describe()
# Out:
# count         943
# unique         21
# top       student
# freq          196
# Name: occupation, dtype: object

# %%
# Step 17. What is the mean age of users?

age_mean = users.age.mean()
print('Mean age of users:',age_mean)
# Out:
# Mean age of users: 34.05196182396607

# %%
# Step 18. What is the age with least occurrence?

age_counts = users['age'].value_counts()
least_occurrence_age = age_counts.idxmin()

print("Age with least occurrence:", least_occurrence_age)
# Out:
# Age with least occurrence: 7

# %% [markdown]
# #

# %% [markdown]
# # Ex 1 Filtering and Sorting Data

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
# Step 2. Import the dataset from this address.

chipo = pd.read_csv('chipotle.csv')

# %%
# Step 3. Assign it to a variable called chipo.

chipo
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
# Step 4. How many products cost more than $10.00?

chipo.item_price = [float(value[1 : -1]) for value in chipo.item_price]
chipo.query('item_price > 10').item_name.nunique()
# Out:
# 31

# %%
# Step 5. What is the price of each item?
# print a data frame with only two columns item_name and item_price

chipo_df = chipo[['item_name','item_price']]
chipo_df
# Out:
#                                   item_name  item_price
# 0              Chips and Fresh Tomato Salsa        2.39
# 1                                      Izze        3.39
# 2                          Nantucket Nectar        3.39
# 3     Chips and Tomatillo-Green Chili Salsa        2.39
# 4                              Chicken Bowl       16.98
# ...                                     ...         ...
# 4617                          Steak Burrito       11.75
# 4618                          Steak Burrito       11.75
# 4619                     Chicken Salad Bowl       11.25
# 4620                     Chicken Salad Bowl        8.75
# 4621                     Chicken Salad Bowl        8.75
#
# [4622 rows x 2 columns]

# %%
# Step 6. Sort by the name of the item

chipo.sort_values(by='item_name')
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %%
# Step 7. What was the quantity of the most expensive item ordered?

chipo.sort_values(by = "item_price", ascending = False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
# Step 8. How many times was a Veggie Salad Bowl ordered?

chipo[chipo.item_name == 'Veggie Salad Bowl'].shape[0]
# Out:
# 18

# %%
# Step 9. How many times did someone order more than one Canned Soda?

chipo[(chipo.item_name == 'Canned Soda') & (chipo.quantity > 1)].shape[0]
# Out:
# 20

# %% [markdown]
# #

# %% [markdown]
# # Ex2 - Filtering and Sorting Data

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
# Step 2. Import the dataset from this address

euro12 = pd.read_csv('Euro_2012_stats_TEAM.csv')

# %%
# Step 3. Assign it to a variable called euro12.

euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 4. Select only the Goal column.

euro12[['Goals']]
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %%
# Step 5. How many team participated in the Euro2012?

total_team = euro12['Team'].count()
print('Total team participated in Euro2012 :',total_team)
# Out:
# Total team participated in Euro2012 : 16

# %%
# Step 6. What is the number of columns in the dataset?

col_count = len(euro12.columns)
print("Number of columns in dataset :",col_count)
# Out:
# Number of columns in dataset : 35

# %%
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline

discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
# Step 8. Sort the teams by Red Cards, then to Yellow Cards

discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
# Step 9. Calculate the mean Yellow Cards given per Team

round(discipline['Yellow Cards'].mean())
# Out:
# 7

# %%
# Step 10. Filter teams that scored more than 6 goals

euro12[euro12.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
# Step 11. Select the teams that start with G

euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
# Step 12. Select the first 7 columns

euro12.iloc[:,0:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 13. Select all columns except the last 3.

euro12.iloc[: , :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
# Step 14. Present only the Shooting Accuracy from England,Italy and Russia

euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# #

# %% [markdown]
# # Fictional Army - Filtering and Sorting

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
# Step 2. This is the data given as a dictionary

# Create an example dataframe about a fictional army
raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
            'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'],
            'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
            'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
            'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
            'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
            'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
            'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
            'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
            'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washington', 'Oregon', 'Wyoming', 'Louisana', 'Georgia']}

# %%
# Step 3. Create a dataframe and assign it to a variable called army.
# Don't forget to include the columns names in the order presented in the dictionary ('regiment', 'company', 'deaths'...) so that 
# the column index order is consistent with the solutions. If omitted, pandas will order the columns alphabetically.

army = pd.DataFrame(data=raw_data)
army
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# ...

# %%
# Step 4. Set the 'origin' colum as the index of the dataframe

army.set_index('origin', inplace=True)

# %%
# Step 5. Print only the column veterans

army[['veterans']]
# Out:
#             veterans
# origin
# Arizona            1
# California         5
# Texas             62
# Florida           26
# Maine             73
# Iowa              37
# Alaska           949
# Washington        48
# Oregon            48
# Wyoming          435
# Louisana          63
# Georgia          345

# %%
# Step 6. Print the columns 'veterans' and 'deaths'

army[['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washington        48      62
# Oregon            48      62
# Wyoming          435      73
# Louisana          63      37
# Georgia          345      35

# %%
# Step 7. Print the name of all the columns.

army.columns
# Out:
# Index(['regiment', 'company', 'deaths', 'battles', 'size', 'veterans',
#        'readiness', 'armored', 'deserters'],
#       dtype='object')

# %%
# Step 8. Select the 'deaths', 'size' and 'deserters' columns from Maine and Alaska

army.loc[["Maine", "Alaska"], ["deaths", "size", "deserters"]]
# Out:
#         deaths  size  deserters
# origin
# Maine       43  1592          3
# Alaska     523   987         24

# %%
# Step 9. Select the rows 3 to 7 and the columns 3 to 6

army.iloc[2:7, 2:6]
# Out:
#          deaths  battles  size  veterans
# origin
# Texas        25        2  1099        62
# Florida     616        2  1400        26
# Maine        43        4  1592        73
# Iowa        234        7  1006        37
# Alaska      523        8   987       949

# %%
# Step 10. Select every row after the fourth row and all columns

army.iloc[4:, :]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine       Dragoons     1st      43        4  1592        73          2
# Iowa        Dragoons     1st     234        7  1006        37          1
# Alaska      Dragoons     2nd     523        8   987       949          2
# Washington  Dragoons     2nd      62        3   849        48          3
# Oregon        Scouts     1st      62        4   973        48          2
# Wyoming       Scouts     1st      73        7  1005       435          1
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# Georgia           1          3

# %%
# Step 11. Select every row up to the 4th row and all columns

army.iloc[:4, :]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %%
# Step 12. Select the 3rd column up to the 7th column

army.iloc[: , 2:7]
# Out:
#             deaths  battles  size  veterans  readiness
# origin
# Arizona        523        5  1045         1          1
# California      52       42   957         5          2
# Texas           25        2  1099        62          3
# Florida        616        2  1400        26          3
# Maine           43        4  1592        73          2
# Iowa           234        7  1006        37          1
# Alaska         523        8   987       949          2
# Washington      62        3   849        48          3
# Oregon          62        4   973        48          2
# Wyoming         73        7  1005       435          1
# Louisana        37        8  1099        63          2
# Georgia         35        9  1523       345          3

# %%
# Step 13. Select rows where df.deaths is greater than 50

army[army["deaths"] > 50]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washington    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Florida           1          2
# Iowa              1          4
# Alaska            0         24
# Washington        1         31
# Oregon            0          2
# ...

# %%
# Step 14. Select rows where df.deaths is greater than 500 or less than 50

army[(army["deaths"] > 500) | (army["deaths"] < 50)]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona   Nighthawks     1st     523        5  1045         1          1
# Texas     Nighthawks     2nd      25        2  1099        62          3
# Florida   Nighthawks     2nd     616        2  1400        26          3
# Maine       Dragoons     1st      43        4  1592        73          2
# Alaska      Dragoons     2nd     523        8   987       949          2
# Louisana      Scouts     2nd      37        8  1099        63          2
# Georgia       Scouts     2nd      35        9  1523       345          3
#
#           armored  deserters
# origin
# Arizona         1          4
# Texas           1         31
# Florida         1          2
# Maine           0          3
# Alaska          0         24
# Louisana        1          2
# Georgia         1          3

# %%
# Step 15. Select all the regiments not named "Dragoons"

army[army["regiment"] != "Dragoons"]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Louisana        Scouts     2nd      37        8  1099        63          2
# Georgia         Scouts     2nd      35        9  1523       345          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Oregon            0          2
# Wyoming           0          3
# Louisana          1          2
# ...

# %%
# Step 16. Select the rows called Texas and Arizona

army.loc[["Texas", "Arizona"], :]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %%
# Step 17. Select the third cell in the row named Arizona

army.loc[["Arizona"]].iloc[:, 2]
# Out:
# origin
# Arizona    523
# Name: deaths, dtype: int64

# %%
# Step 18. Select the third cell down in the column named deaths

army.loc[:, ["deaths"]].iloc[2]
# Out:
# deaths    25
# Name: Texas, dtype: int64

# %% [markdown]
# #

# %% [markdown]
# # Ex - GroupBy

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
#Step 2. Import the dataset from this address.

drinks = pd.read_csv('drinks.csv')

# %%
# Step 3. Assign it to a variable called drinks.

drinks
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
# Step 4. Which continent drinks more beer on average?

drinks.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
# Step 5. For each continent print the statistics for wine consumption.

drinks.groupby('continent').wine_servings.describe()
# Out:
#                count        mean        std  min   25%    50%     75%    max
# continent
# Africa          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# Asia            44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# Europe          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# North America   23.0   24.521739  28.266378  1.0   5.0   11.0   34.00  100.0
# Oceania         16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# South America   12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %%
# Step 6. Print the mean alcohol consumption per continent for every column

drinks.groupby('continent').mean()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3044\3550437200.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   drinks.groupby('continent').mean()
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# ...

# %%
# Step 7. Print the median alcohol consumption per continent for every column

drinks.groupby('continent').median()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3044\2459943447.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   drinks.groupby('continent').median()
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa                  32.0              3.0            2.0
# Asia                    17.5             16.0            1.0
# Europe                 219.0            122.0          128.0
# North America          143.0            137.0           11.0
# Oceania                 52.5             37.0            8.5
# South America          162.5            108.5           12.0
#
#                total_litres_of_pure_alcohol
# continent
# Africa                                 2.30
# Asia                                   1.20
# ...

# %%
# Step 8. Print the mean, min and max values for spirit consumption.

drinks.groupby('continent').spirit_servings.agg(['mean', 'min', 'max'])
# Out:
#                      mean  min  max
# continent
# Africa          16.339623    0  152
# Asia            60.840909    0  326
# Europe         132.555556    0  373
# North America  165.739130   68  438
# Oceania         58.437500    0  254
# South America  114.750000   25  302

# %% [markdown]
# #

# %% [markdown]
# # Occupation

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
# Step 2. Import the dataset from this address.

users = pd.read_csv('user.csv')

# %%
# Step 3. Assign it to a variable called users.

users
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
# Step 4. Discover what is the mean age per occupation

users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
# Step 6. For each occupation, calculate the minimum and maximum ages

users.groupby('occupation').age.agg(['min', 'max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
# Step 7. For each combination of occupation and gender, calculate the mean age

users.groupby(['occupation', 'gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
# Step 8. For each occupation present the percentage of women and men

# %% [markdown]
# #

# %% [markdown]
# # Regiment

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
# Step 2. Create the DataFrame with the following values.

raw_data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 
                         'Scouts', 'Scouts', 'Scouts', 'Scouts'], 
        'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd','1st', '1st', '2nd', '2nd'], 
        'name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze', 'Jacon', 'Ryaner', 'Sone', 'Sloan', 'Piger', 'Riani', 'Ali'], 
        'preTestScore': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70, 25, 94, 57, 62, 70, 62, 70]}

# %%
# Step 3. Assign it to a variable called regiment.

regiment = pd.DataFrame(raw_data, columns = raw_data.keys())
regiment
# Out:
#       regiment company      name  preTestScore  postTestScore
# 0   Nighthawks     1st    Miller             4             25
# 1   Nighthawks     1st  Jacobson            24             94
# 2   Nighthawks     2nd       Ali            31             57
# 3   Nighthawks     2nd    Milner             2             62
# 4     Dragoons     1st     Cooze             3             70
# 5     Dragoons     1st     Jacon             4             25
# 6     Dragoons     2nd    Ryaner            24             94
# 7     Dragoons     2nd      Sone            31             57
# 8       Scouts     1st     Sloan             2             62
# 9       Scouts     1st     Piger             3             70
# 10      Scouts     2nd     Riani             2             62
# 11      Scouts     2nd       Ali             3             70

# %%
# Step 4. What is the mean preTestScore from the regiment Nighthawks?

regiment[regiment['regiment'] == 'Nighthawks'].groupby('regiment').mean()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3044\1184691464.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   regiment[regiment['regiment'] == 'Nighthawks'].groupby('regiment').mean()
#             preTestScore  postTestScore
# regiment
# Nighthawks         15.25           59.5

# %%
# Step 5. Present general statistics by company

regiment.groupby('company').describe()
# Out:
#         preTestScore                                                      \
#                count       mean        std  min   25%   50%    75%   max
# company
# 1st              6.0   6.666667   8.524475  2.0  3.00   3.5   4.00  24.0
# 2nd              6.0  15.500000  14.652645  2.0  2.25  13.5  29.25  31.0
#
#         postTestScore
#                 count       mean        std   min    25%   50%   75%   max
# company
# 1st               6.0  57.666667  27.485754  25.0  34.25  66.0  70.0  94.0
# 2nd               6.0  67.000000  14.057027  57.0  58.25  62.0  68.0  94.0

# %%
# Step 6. What is the mean of each company's preTestScore?

regiment.groupby('company').preTestScore.mean()
# Out:
# company
# 1st     6.666667
# 2nd    15.500000
# Name: preTestScore, dtype: float64

# %%
# Step 7. Present the mean preTestScores grouped by regiment and company

regiment.groupby(['regiment', 'company']).preTestScore.mean()
# Out:
# regiment    company
# Dragoons    1st         3.5
#             2nd        27.5
# Nighthawks  1st        14.0
#             2nd        16.5
# Scouts      1st         2.5
#             2nd         2.5
# Name: preTestScore, dtype: float64

# %%
# Step 8. Present the mean preTestScores grouped by regiment and company without heirarchical indexing

regiment.groupby(['regiment', 'company']).preTestScore.mean().unstack()
# Out:
# company      1st   2nd
# regiment
# Dragoons     3.5  27.5
# Nighthawks  14.0  16.5
# Scouts       2.5   2.5

# %%
# Step 9. Group the entire dataframe by regiment and company

regiment.groupby(['regiment', 'company']).mean()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_3044\2263669668.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   regiment.groupby(['regiment', 'company']).mean()
#                     preTestScore  postTestScore
# regiment   company
# Dragoons   1st               3.5           47.5
#            2nd              27.5           75.5
# Nighthawks 1st              14.0           59.5
#            2nd              16.5           59.5
# Scouts     1st               2.5           66.0
#            2nd               2.5           66.0

# %%
# Step 10. What is the number of observations in each regiment and company

regiment.groupby(['company', 'regiment']).size()
# Out:
# company  regiment
# 1st      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# 2nd      Dragoons      2
#          Nighthawks    2
#          Scouts        2
# dtype: int64

# %%
# Step 11. Iterate over a group and print the name and the whole data from the regiment

for a,i in regiment.groupby('regiment'):
    print(a)
    print(i

# %% [markdown]
# #

# %% [markdown]
# # Student Alcohol Consumption

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
# Step 2. Import the dataset from this address.

df = pd.read_csv('student-mat.csv')

# %%
# Step 3. Assign it to a variable called df.

df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

df.loc[: , "school":"guardian"]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      reason guardian
# 0    course   mother
# ...

# %%
# Step 5. Create a lambda function that will capitalize strings.

capitalizer = lambda x: x.capitalize()

# %%
# Step 6. Capitalize both Mjob and Fjob

df['Mjob'].apply(capitalizer)
df['Fjob'].apply(capitalizer)
# Out:
# 0       Teacher
# 1         Other
# 2         Other
# 3      Services
# 4         Other
#          ...
# 390    Services
# 391    Services
# 392       Other
# 393       Other
# 394     At_home
# Name: Fjob, Length: 395, dtype: object

# %%
# Step 7. Print the last elements of the data set.

df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
# Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

df['Mjob'] = df['Mjob'].apply(capitalizer)
df['Fjob'] = df['Fjob'].apply(capitalizer)
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 390     MS   M   20       U     LE3       A     2     2  Services  Services
# 391     MS   M   17       U     LE3       T     3     1  Services  Services
# 392     MS   M   21       R     GT3       T     1     1     Other     Other
# 393     MS   M   18       R     LE3       T     3     2  Services     Other
# 394     MS   M   19       U     LE3       T     1     1     Other   At_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [5 rows x 33 columns]

# %%
# Step 9. Create a function called majority that returns a boolean value to a new column called legal_drinker 
# (Consider majority as older than 17 years old)

def majority(x):
    if x > 17:
        return True
    else:
        return False
    
df['legal_drinker'] = df['age'].apply(majority)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  At_home   Teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  At_home     Other  ...
# 2     GP   F   15       U     LE3       T     1     1  At_home     Other  ...
# 3     GP   F   15       U     GT3       T     4     2   Health  Services  ...
# 4     GP   F   16       U     GT3       T     3     3    Other     Other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3 legal_drinker
# 0        3     4     1     1       3        6   5   6   6          True
# 1        3     3     1     1       3        4   5   5   6         False
# 2        3     2     2     3       3       10   7   8  10         False
# 3        2     2     1     1       5        2  15  14  15         False
# 4        3     2     1     2       5        4   6  10  10         False
#
# [5 rows x 34 columns]

# %%
# Step 10. Multiply every number of the dataset by 10.

def times10(x):
    if type(x) is int:
        return 10 * x
    return x
df.applymap(times10).head(10)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0     GP   F  180       U     GT3       A    40    40   At_home   Teacher
# 1     GP   F  170       U     GT3       T    10    10   At_home     Other
# 2     GP   F  150       U     LE3       T    10    10   At_home     Other
# 3     GP   F  150       U     GT3       T    40    20    Health  Services
# 4     GP   F  160       U     GT3       T    30    30     Other     Other
# 5     GP   M  160       U     LE3       T    40    30  Services     Other
# 6     GP   M  160       U     LE3       T    20    20     Other     Other
# 7     GP   F  170       U     GT3       A    40    40     Other   Teacher
# 8     GP   M  150       U     LE3       A    30    20  Services     Other
# 9     GP   M  150       U     GT3       T    30    40     Other     Other
#
#    ... freetime goout  Dalc  Walc  health absences   G1   G2   G3  \
# 0  ...       30    40    10    10      30       60   50   60   60
# ...

# %% [markdown]
# #

# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %%
# Step 1. Import the necessary libraries

import numpy as np
import pandas as pd

# %%
# Step 2. Import the dataset from this address.

crime = pd.read_csv('US_Crime_Rates_1960_2014.csv')

# %%
# Step 3. Assign it to a variable called crime.

crime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %%
# Step 4. What is the type of the columns?

crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
# Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
# Step 5. Convert the type of the column Year to datetime64

crime.Year = pd.to_datetime(crime.Year, format='%Y')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
# Step 6. Set the Year column as the index of the dataframe

crime = crime.set_index('Year', drop = True)
crime
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175   3384200   288460   3095700    9110          17190
# 1961-01-01   182992000   3488000   289390   3198600    8740          17220
# 1962-01-01   185771000   3752200   301510   3450700    8530          17550
# 1963-01-01   188483000   4109500   316970   3792500    8640          17650
# 1964-01-01   191141000   4564600   364220   4200400    9360          21420
# 1965-01-01   193526000   4739400   387390   4352000    9960          23410
# 1966-01-01   195576000   5223500   430180   4793300   11040          25820
# 1967-01-01   197457000   5903400   499930   5403500   12240          27620
# 1968-01-01   199399000   6720200   595010   6125200   13800          31670
# 1969-01-01   201385000   7410900   661870   6749000   14760          37170
# 1970-01-01   203235298   8098000   738820   7359200   16000          37990
# ...

# %%
# Step 7. Delete the Total column

crime.drop(columns = ['Total'], inplace = True)

# %%
# Step 8. Group the year by decades and sum the values
# Pay attention to the Population column number, summing this column is a mistake

# %%
# Step 9. What is the most dangerous decade to live in the US?

# %% [markdown]
# #

# %% [markdown]
# # MPG Cars

# %%
# Step 1. Import the necessary libraries

import numpy as np
import pandas as pd

# %%
# Step 2. Import the first dataset cars1 and cars2.

cars1 = pd.read_csv('cars1.csv')
cars2 = pd.read_csv('cars2.csv')

# %%
# Step 3. Assign each to a variable called cars1 and cars2

print(cars1)
print(cars2)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 193  24.0          6           200         81    3012          17.6     76
# 194  22.5          6           232         90    3085          17.6     76
# 195  29.0          4            85         52    2035          22.2     76
# 196  24.5          4            98         60    2164          22.1     76
# 197  29.0          4            90         70    1937          14.2     76
#
# ...

# %%
# Step 4. Oops, it seems our first dataset has some unnamed blank columns, fix cars1

cars1 = cars1.loc[:, "mpg":"car"]
cars1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
# 3  16.0          8           304        150    3433          12.0     70
# 4  17.0          8           302        140    3449          10.5     70
#
#    origin                        car
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# Step 5. What is the number of observations in each dataset?

print('Observations of cars1:',cars1.shape)
print('Observations of cars2:',cars2.shape)
# Out:
# Observations of cars1: (198, 9)
# Observations of cars2: (200, 9)

# %%
# Step 6. Join cars1 and cars2 into a single DataFrame called cars

cars = cars1.append(cars2)
cars
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15600\2664858765.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   cars = cars1.append(cars2)
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# ...

# %%
# Step 7. Oops, there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

nr_owners = np.random.randint(15000, high=73001, size=398, dtype='l')
nr_owners
# Out:
# array([58598, 67634, 15532, 25354, 22887, 31616, 18515, 36373, 33308,
#        26968, 38970, 28373, 34614, 45736, 25797, 30795, 15224, 36153,
#        52709, 50421, 44313, 28975, 24178, 40730, 44596, 17923, 22701,
#        25302, 61077, 70656, 66438, 64245, 49875, 65558, 55063, 29473,
#        72548, 50998, 24154, 70204, 39016, 35894, 35146, 16965, 59722,
#        22609, 65448, 16412, 41343, 61861, 67788, 43582, 34632, 55572,
#        50248, 58724, 28481, 23153, 41869, 60856, 27953, 30920, 69938,
#        20143, 49712, 69275, 67003, 61025, 41694, 46862, 23206, 50407,
#        45041, 15368, 45822, 25375, 22865, 48805, 45557, 36888, 37241,
#        32192, 48636, 30181, 21181, 51942, 29933, 52574, 30774, 62922,
#        50465, 70567, 71715, 68284, 16804, 21046, 62617, 50954, 45965,
#        32381, 16646, 60441, 62587, 62261, 29603, 69907, 41186, 43764,
#        44313, 47759, 46832, 26821, 70154, 56898, 25569, 38874, 48379,
# ...

# %%
# Step 8. Add the column owners to cars 

cars['owners'] = nr_owners
cars
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car  owners
# ...

# %% [markdown]
# #

# %% [markdown]
# # Fictitious Names

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
# Step 2. Create the 3 DataFrames based on the following raw data

raw_data_1 = {
 'subject_id': ['1', '2', '3', '4', '5'],
 'first_name': ['Alex', 'Amy', 'Allen', 'Alice', 'Ayoung'],
 'last_name': ['Anderson', 'Ackerman', 'Ali', 'Aoni', 'Atiches']}
raw_data_2 = {
 'subject_id': ['4', '5', '6', '7', '8'],
 'first_name': ['Billy', 'Brian', 'Bran', 'Bryce', 'Betty'],
 'last_name': ['Bonder', 'Black', 'Balwner', 'Brice', 'Btisan']}
raw_data_3 = {
 'subject_id': ['1', '2', '3', '4', '5', '7', '8', '9', '10', '11'],
 'test_id': [51, 15, 15, 61, 16, 14, 15, 1, 61, 16]}

# %%
# Step 3. Assign each to a variable called data1, data2, data3

data1 = pd.DataFrame(raw_data_1)
data2 = pd.DataFrame(raw_data_2)
data3 = pd.DataFrame(raw_data_3)

# %%
# Step 4. Join the two dataframes along rows and assign all_data

all_data = data1.append(data2)
all_data
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_15600\1366968914.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_data = data1.append(data2)
#   subject_id first_name last_name
# 0          1       Alex  Anderson
# 1          2        Amy  Ackerman
# 2          3      Allen       Ali
# 3          4      Alice      Aoni
# 4          5     Ayoung   Atiches
# 0          4      Billy    Bonder
# 1          5      Brian     Black
# 2          6       Bran   Balwner
# 3          7      Bryce     Brice
# 4          8      Betty    Btisan

# %%
# Step 5. Join the two dataframes along columns and assing to all_data_col

all_data_col = pd.concat([data1, data2], axis = 1)
all_data_col
# Out:
#   subject_id first_name last_name subject_id first_name last_name
# 0          1       Alex  Anderson          4      Billy    Bonder
# 1          2        Amy  Ackerman          5      Brian     Black
# 2          3      Allen       Ali          6       Bran   Balwner
# 3          4      Alice      Aoni          7      Bryce     Brice
# 4          5     Ayoung   Atiches          8      Betty    Btisan

# %%
# Step 6. Print data3

data3
# Out:
#   subject_id  test_id
# 0          1       51
# 1          2       15
# 2          3       15
# 3          4       61
# 4          5       16
# 5          7       14
# 6          8       15
# 7          9        1
# 8         10       61
# 9         11       16

# %%
# Step 7. Merge all_data and data3 along the subject_id value

pd.merge(all_data, data3, on='subject_id')
# Out:
#   subject_id first_name last_name  test_id
# 0          1       Alex  Anderson       51
# 1          2        Amy  Ackerman       15
# 2          3      Allen       Ali       15
# 3          4      Alice      Aoni       61
# 4          4      Billy    Bonder       61
# 5          5     Ayoung   Atiches       16
# 6          5      Brian     Black       16
# 7          7      Bryce     Brice       14
# 8          8      Betty    Btisan       15

# %%
# Step 8. Merge only the data that has the same 'subject_id' on both data1 and data2

pd.merge(data1, data2, on='subject_id', how='inner')         # how = 'inner' -->intersection of keys from both frames (defult)
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          4        Alice        Aoni        Billy      Bonder
# 1          5       Ayoung     Atiches        Brian       Black

# %%
# Step 9. Merge all values in data1 and data2, with matching records from both sides where available.

pd.merge(data1, data2, on='subject_id', how='outer' )       # how = 'outer' -->union of keys from both frames
# Out:
#   subject_id first_name_x last_name_x first_name_y last_name_y
# 0          1         Alex    Anderson          NaN         NaN
# 1          2          Amy    Ackerman          NaN         NaN
# 2          3        Allen         Ali          NaN         NaN
# 3          4        Alice        Aoni        Billy      Bonder
# 4          5       Ayoung     Atiches        Brian       Black
# 5          6          NaN         NaN         Bran     Balwner
# 6          7          NaN         NaN        Bryce       Brice
# 7          8          NaN         NaN        Betty      Btisan

# %% [markdown]
# #

# %% [markdown]
# # Housing Market

# %%
# Step 1. Import the necessary libraries

import pandas as pd
import numpy as np

# %%
# Step 2. Create 3 differents Series, each of length 100, as follows:
# 1. The first a random number from 1 to 4
# 2. The second a random number from 1 to 3
# 3. The third a random number from 10,000 to 30,000

s1 = pd.Series(np.random.randint(1, high=5, size=100, dtype='l'))
s2 = pd.Series(np.random.randint(1, high=3, size=100, dtype='l'))
s3 = pd.Series(np.random.randint(10000, high=30000, size=100, dtype='l'))

print(s1,s2,s3)
# Out:
# 0     4
# 1     2
# 2     1
# 3     1
# 4     1
#      ..
# 95    1
# 96    3
# 97    3
# 98    1
# 99    2
# Length: 100, dtype: int32 0     1
# 1     2
# 2     1
# 3     2
# 4     1
#      ..
# 95    1
# 96    2
# 97    1
# 98    2
# 99    2
# Length: 100, dtype: int32 0     28417
# 1     23781
# 2     21800
# 3     27552
# 4     24703
#       ...
# 95    26286
# 96    15795
# 97    26985
# 98    16771
# 99    11813
# Length: 100, dtype: int32

# %%
# Step 3. Let's create a DataFrame by joinning the Series by column

df = pd.concat([s1, s2, s3], axis=1)
df.head()
# Out:
#    0  1      2
# 0  4  1  28417
# 1  2  2  23781
# 2  1  1  21800
# 3  1  2  27552
# 4  1  1  24703

# %%
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

df.rename(columns = {0: 'bedrs', 1: 'bathrs', 2: 'price_sqr_meter'}, inplace=True)
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       4       1            28417
# 1       2       2            23781
# 2       1       1            21800
# 3       1       2            27552
# 4       1       1            24703
# ..    ...     ...              ...
# 95      1       1            26286
# 96      3       2            15795
# 97      3       1            26985
# 98      1       2            16771
# 99      2       2            11813
#
# [100 rows x 3 columns]

# %%
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'

bigcolumn = pd.concat([s1, s2, s3], axis=0)
bigcolumn = bigcolumn.to_frame()
bigcolumn
# Out:
#         0
# 0       4
# 1       2
# 2       1
# 3       1
# 4       1
# ..    ...
# 95  26286
# 96  15795
# 97  26985
# 98  16771
# 99  11813
#
# [300 rows x 1 columns]

# %%
# Step 6. Oops, it seems it is going only until index 99. Is it true?

# no the index are kept but the length of the DataFrame is 300
len(bigcolumn)
# Out:
# 300

# %%
# Step 7. Reindex the DataFrame so it goes from 0 to 299

bigcolumn.reset_index(drop=True, inplace=True)
bigcolumn
# Out:
#          0
# 0        4
# 1        2
# 2        1
# 3        1
# 4        1
# ..     ...
# 295  26286
# 296  15795
# 297  26985
# 298  16771
# 299  11813
#
# [300 rows x 1 columns]

# %% [markdown]
# #

# %% [markdown]
# # US - Baby Names

# %%
# Step 1. Import the necessary libraries

import pandas as pd

# %%
# Step 2. Import the dataset from this address.

baby_names = pd.read_csv('US_Baby_Names_right.csv')

# %%
# Step 3. Assign it to a variable called baby_names.

baby_names
# Out:
#          Unnamed: 0       Id     Name  Year Gender State  Count
# 0             11349    11350     Emma  2004      F    AK     62
# 1             11350    11351  Madison  2004      F    AK     48
# 2             11351    11352   Hannah  2004      F    AK     46
# 3             11352    11353    Grace  2004      F    AK     44
# 4             11353    11354    Emily  2004      F    AK     41
# ...             ...      ...      ...   ...    ...   ...    ...
# 1016390     5647421  5647422     Seth  2014      M    WY      5
# 1016391     5647422  5647423  Spencer  2014      M    WY      5
# 1016392     5647423  5647424     Tyce  2014      M    WY      5
# 1016393     5647424  5647425   Victor  2014      M    WY      5
# 1016394     5647425  5647426   Waylon  2014      M    WY      5
#
# [1016395 rows x 7 columns]

# %%
# Step 4. See the first 10 entries

baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name  Year Gender State  Count
# 0       11349  11350      Emma  2004      F    AK     62
# 1       11350  11351   Madison  2004      F    AK     48
# 2       11351  11352    Hannah  2004      F    AK     46
# 3       11352  11353     Grace  2004      F    AK     44
# 4       11353  11354     Emily  2004      F    AK     41
# 5       11354  11355   Abigail  2004      F    AK     37
# 6       11355  11356    Olivia  2004      F    AK     33
# 7       11356  11357  Isabella  2004      F    AK     30
# 8       11357  11358    Alyssa  2004      F    AK     29
# 9       11358  11359    Sophia  2004      F    AK     28

# %%
# Step 5. Delete the column 'Unnamed: 0' and 'Id'

baby_names.drop(columns = 'Id' , inplace = True)
baby_names.drop(columns = 'Unnamed: 0' , inplace = True)

baby_names
# Out:
#             Name  Year Gender State  Count
# 0           Emma  2004      F    AK     62
# 1        Madison  2004      F    AK     48
# 2         Hannah  2004      F    AK     46
# 3          Grace  2004      F    AK     44
# 4          Emily  2004      F    AK     41
# ...          ...   ...    ...   ...    ...
# 1016390     Seth  2014      M    WY      5
# 1016391  Spencer  2014      M    WY      5
# 1016392     Tyce  2014      M    WY      5
# 1016393   Victor  2014      M    WY      5
# 1016394   Waylon  2014      M    WY      5
#
# [1016395 rows x 5 columns]

# %%
# Step 6. Is there more male or female names in the dataset?

baby_names['Gender'].value_counts()
# Out:
# F    558846
# M    457549
# Name: Gender, dtype: int64

# %%
# Step 7. Group the dataset by name and assign to names

names = baby_names.groupby("Name").sum()
print(names.shape)
names.sort_values("Count", ascending = 0)
# Out:
# (17632, 1)
# C:\Users\asus\AppData\Local\Temp\ipykernel_6640\2485584673.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   names = baby_names.groupby("Name").sum()
#              Count
# Name
# Jacob       242874
# Emma        214852
# Michael     214405
# Ethan       209277
# Isabella    204798
# ...            ...
# Eniola           5
# Atlantis         5
# Marci            5
# Simarpreet       5
# Nita             5
#
# [17632 rows x 1 columns]

# %%
# Step 8. How many different names exist in the dataset?

len(names)
# Out:
# 17632

# %%
# Step 9. What is the name with most occurrences?

names.Count.idxmax()
# Out:
# 'Jacob'

# %%
# Step 10. How many different names have the least occurrences?

len(names[names.Count == names.Count.min()])
# Out:
# 2578

# %%
# Step 11. What is the median name occurrence?

names[names.Count == names.Count.median()]
# Out:
#          Count
# Name
# Aishani     49
# Alara       49
# Alysse      49
# Ameir       49
# Anely       49
# ...        ...
# Sriram      49
# Trinton     49
# Vita        49
# Yoni        49
# Zuleima     49
#
# [66 rows x 1 columns]

# %%
# Step 12. What is the standard deviation of names?

names.Count.std()
# Out:
# 11006.069467891111

# %%
# Step 13. Get a summary with the mean, min, max, std and quartiles.

names.describe()
# Out:
#                Count
# count   17632.000000
# mean     2008.932169
# std     11006.069468
# min         5.000000
# 25%        11.000000
# 50%        49.000000
# 75%       337.000000
# max    242874.000000
